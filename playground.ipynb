# %%
from node_clouds import uniform_node_clouds,print_cloud

# %%
Lx = 10
Ly = 10
delta = 0.1
Npoints = 1000
line_share = 0.4

# %%
points = uniform_node_clouds(Lx, Ly, delta, Npoints, line_share)

# %%
print_cloud(points, Lx, Ly, delta)
